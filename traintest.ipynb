# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('train.csv')

# %%
df1.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df2 = pd.read_csv('test.csv')

# %%
df2
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
#Merging both data
df1 = pd.concat([df1,df2])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# ...

# %%
df1
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df1.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         Product_Category_2  Product_Category_3  Purchase
# 233594                 NaN                 NaN       NaN
# ...

# %%
df1.drop(['User_ID'], axis =1, inplace =True)
#axis = 0 == row wise -horizontally 
#axis = 1 == column wise -vertically
df1.head()
# Out:
#   Product_ID Gender   Age  Occupation City_Category  \
# 0  P00069042      F  0-17          10             A
# 1  P00248942      F  0-17          10             A
# 2  P00087842      F  0-17          10             A
# 3  P00085442      F  0-17          10             A
# 4  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df1['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
pd.get_dummies(df1["Gender"], drop_first=True)
# Out:
#             M
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
# ...       ...
# 233594  False
# 233595  False
# 233596  False
# 233597  False
# 233598  False
#
# [783667 rows x 1 columns]

# %%
df1['Gender'] =df1['Gender'].map({'F':0,'M':1})
df1.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042       0  0-17          10             A
# 1  P00248942       0  0-17          10             A
# 2  P00087842       0  0-17          10             A
# 3  P00085442       0  0-17          10             A
# 4  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df1['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
#pd.get_dummies(df1['Age'], drop_first=True)

# %%
df1['Age'] =df1['Age'].map({'0-17':1,'18-25':2,'26-35':3,'36-45' :4,
                        '46-50':5,'51-55':6,'55+':7})
df1.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df1['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df_city=pd.get_dummies(df1['City_Category'],drop_first=True)

# %%
df1= pd.concat([df1,df_city])
df1.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042     0.0  1.0        10.0             A
# 1  P00248942     0.0  1.0        10.0             A
# 2  P00087842     0.0  1.0        10.0             A
# 3  P00085442     0.0  1.0        10.0             A
# 4  P00285442     1.0  7.0        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase    B    C
# 0                 NaN                 NaN    8370.0  NaN  NaN
# 1                 6.0                14.0   15200.0  NaN  NaN
# 2                 NaN                 NaN    1422.0  NaN  NaN
# ...

# %%
df1.drop('City_Category', axis = 1, inplace =True)
df1.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042     0.0  1.0        10.0                          2
# 1  P00248942     0.0  1.0        10.0                          2
# 2  P00087842     0.0  1.0        10.0                          2
# 3  P00085442     0.0  1.0        10.0                          2
# 4  P00285442     1.0  7.0        16.0                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0             0.0                 3.0                 NaN                 NaN
# 1             0.0                 1.0                 6.0                14.0
# 2             0.0                12.0                 NaN                 NaN
# 3             0.0                12.0                14.0                 NaN
# 4             0.0                 8.0                 NaN                 NaN
#
#    Purchase    B    C
# 0    8370.0  NaN  NaN
# 1   15200.0  NaN  NaN
# 2    1422.0  NaN  NaN
# ...

# %%
#Check  MISSING VALUES
df1.isnull().sum()
# Out:
# Product_ID                     783667
# Gender                         783667
# Age                            783667
# Occupation                     783667
# Stay_In_Current_City_Years     783667
# Marital_Status                 783667
# Product_Category_1             783667
# Product_Category_2            1029649
# Product_Category_3            1329476
# Purchase                      1017266
# B                              783667
# C                              783667
# dtype: int64

# %%
#focus on replacing the missing values
df1['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df1['Product_Category_2'].mode()[0]
# Out:
# 8.0

# %%
df1['Product_Category_2']=df1['Product_Category_2'].fillna(df1['Product_Category_2'].mode()[0])

# %%
df1['Product_Category_2'].isnull().sum()
# Out:
# 0

# %%
#Product category_3
df1['Product_Category_3'].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df1['Product_Category_2'].value_counts()
# Out:
# Product_Category_2
# 8.0     1120966
# 14.0      78834
# 2.0       70498
# 16.0      61687
# 15.0      54114
# 5.0       37165
# 4.0       36705
# 6.0       23575
# 11.0      20230
# 17.0      19104
# 13.0      15054
# 9.0        8177
# 12.0       7801
# 10.0       4420
# 3.0        4123
# 18.0       4027
# 7.0         854
# Name: count, dtype: int64

# %%
#Replace the Missing values with mode
df1['Product_Category_3'] = df1['Product_Category_3'].fillna(df1['Product_Category_3'].mode()[0])

# %%
df1['Product_Category_3'].isnull().sum()
# Out:
# 0

# %%
df1['Product_Category_3']
# Out:
# 0         16.0
# 1         14.0
# 2         16.0
# 3         16.0
# 4         16.0
#           ...
# 233594    16.0
# 233595    16.0
# 233596    16.0
# 233597    16.0
# 233598    16.0
# Name: Product_Category_3, Length: 1567334, dtype: float64

# %%
df1['Product_Category_3'].isnull().sum()
# Out:
# 0

# %%
df1.shape
# Out:
# (1567334, 12)

# %%
df1['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0', nan], dtype=object)

# %%
df1['Stay_In_Current_City_Years']=df1['Stay_In_Current_City_Years'].str.replace('+','')

# %%
df1.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042     0.0  1.0        10.0                          2
# 1  P00248942     0.0  1.0        10.0                          2
# 2  P00087842     0.0  1.0        10.0                          2
# 3  P00085442     0.0  1.0        10.0                          2
# 4  P00285442     1.0  7.0        16.0                          4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0             0.0                 3.0                 8.0                16.0
# 1             0.0                 1.0                 6.0                14.0
# 2             0.0                12.0                 8.0                16.0
# 3             0.0                12.0                14.0                16.0
# 4             0.0                 8.0                 8.0                16.0
#
#    Purchase    B    C
# 0    8370.0  NaN  NaN
# 1   15200.0  NaN  NaN
# 2    1422.0  NaN  NaN
# ...

# %%
df1
# Out:
#        Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0       P00069042     0.0  1.0        10.0                          2
# 1       P00248942     0.0  1.0        10.0                          2
# 2       P00087842     0.0  1.0        10.0                          2
# 3       P00085442     0.0  1.0        10.0                          2
# 4       P00285442     1.0  7.0        16.0                          4
# ...           ...     ...  ...         ...                        ...
# 233594        NaN     NaN  NaN         NaN                        NaN
# 233595        NaN     NaN  NaN         NaN                        NaN
# 233596        NaN     NaN  NaN         NaN                        NaN
# 233597        NaN     NaN  NaN         NaN                        NaN
# 233598        NaN     NaN  NaN         NaN                        NaN
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1567334 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   Product_ID                  783667 non-null   object
#  1   Gender                      783667 non-null   float64
#  2   Age                         783667 non-null   float64
#  3   Occupation                  783667 non-null   float64
#  4   Stay_In_Current_City_Years  783667 non-null   object
#  5   Marital_Status              783667 non-null   float64
#  6   Product_Category_1          783667 non-null   float64
#  7   Product_Category_2          1567334 non-null  float64
#  8   Product_Category_3          1567334 non-null  float64
#  9   Purchase                    550068 non-null   float64
#  10  B                           783667 non-null   object
#  11  C                           783667 non-null   object
# dtypes: float64(8), object(4)
# ...

# %%
df1.isnull()
# Out:
#         Product_ID  Gender    Age  Occupation  Stay_In_Current_City_Years  \
# 0            False   False  False       False                       False
# 1            False   False  False       False                       False
# 2            False   False  False       False                       False
# 3            False   False  False       False                       False
# 4            False   False  False       False                       False
# ...            ...     ...    ...         ...                         ...
# 233594        True    True   True        True                        True
# 233595        True    True   True        True                        True
# 233596        True    True   True        True                        True
# 233597        True    True   True        True                        True
# 233598        True    True   True        True                        True
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
#df1['Stay_In_Current_City_Years']= df1['Stay_In_Current_City_Years'].map({'False' : 0})

# %%
#convert object into integer
df1['Stay_In_Current_City_Years']=df1['Stay_In_Current_City_Years'].astype('int', errors="ignore")
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1567334 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   Product_ID                  783667 non-null   object
#  1   Gender                      783667 non-null   float64
#  2   Age                         783667 non-null   float64
#  3   Occupation                  783667 non-null   float64
#  4   Stay_In_Current_City_Years  783667 non-null   object
#  5   Marital_Status              783667 non-null   float64
#  6   Product_Category_1          783667 non-null   float64
#  7   Product_Category_2          1567334 non-null  float64
#  8   Product_Category_3          1567334 non-null  float64
#  9   Purchase                    550068 non-null   float64
#  10  B                           783667 non-null   object
#  11  C                           783667 non-null   object
# dtypes: float64(8), object(4)
# ...

# %%
df1['B']=df1['B'].astype('int',errors='ignore')

# %%
df1['C']=df1['C'].astype('int',errors='ignore')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1567334 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   Product_ID                  783667 non-null   object
#  1   Gender                      783667 non-null   float64
#  2   Age                         783667 non-null   float64
#  3   Occupation                  783667 non-null   float64
#  4   Stay_In_Current_City_Years  783667 non-null   object
#  5   Marital_Status              783667 non-null   float64
#  6   Product_Category_1          783667 non-null   float64
#  7   Product_Category_2          1567334 non-null  float64
#  8   Product_Category_3          1567334 non-null  float64
#  9   Purchase                    550068 non-null   float64
#  10  B                           783667 non-null   object
#  11  C                           783667 non-null   object
# dtypes: float64(8), object(4)
# ...

# %%
df1['Age'].duplicated().any()
# Out:
# True

# %%
df1['Gender'].duplicated().any()
# Out:
# True

# %%
df1_reset=df1.reset_index(drop=True)

# %%
#visualization
sns.barplot(x='Age',y='Purchase',hue = 'Gender', data =df1_reset)
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %% [markdown]
# #### observation: Purchasing of men over women is high whereas the purchase with respect to age is similar

# %%
sns.barplot(x='Occupation', y='Purchase', hue ='Gender',data = df1_reset)
# Out:
# <Axes: xlabel='Occupation', ylabel='Purchase'>

# %%
sns.barplot(x='Product_Category_1', y='Purchase', hue ='Gender',data = df1_reset)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='Purchase'>

# %%
#Feature scaling
df_test = df1[df1['Purchase'].isnull()]

# %%
df_train = df1[-df1['Purchase'].isnull()]

# %%
pip install -U scikit-learn scipy matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\Acer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
X = df_train.drop('Purchase', axis =1)

# %%
X.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042     0.0  1.0        10.0                          2
# 1  P00248942     0.0  1.0        10.0                          2
# 2  P00087842     0.0  1.0        10.0                          2
# 3  P00085442     0.0  1.0        10.0                          2
# 4  P00285442     1.0  7.0        16.0                          4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0             0.0                 3.0                 8.0                16.0
# 1             0.0                 1.0                 6.0                14.0
# 2             0.0                12.0                 8.0                16.0
# 3             0.0                12.0                14.0                16.0
# 4             0.0                 8.0                 8.0                16.0
#
#      B    C
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN

# %%
X.shape
# Out:
# (550068, 11)

# %%
y =df_train['Purchase']

# %%
y.shape
# Out:
# (550068,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
  X, y, test_size=0.33, random_state=42)

# %%
X_train.drop('Product_ID',axis=1, inplace=True)
X_test.drop('Product_ID',axis=1, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %%
#Train your model
