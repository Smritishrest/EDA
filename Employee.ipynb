# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Reading the csv file

# %%
df = pd.read_csv("Employee.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df.columns
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot'],
#       dtype='object')

# %% [markdown]
# ## Renaming columns

# %%
df.rename(columns={'JoiningYear':'YearJoined'}, inplace = True) # use inplace = True for permanent change

# %%
df.nunique()  ### UNIQUE VALUES IN EACH COLUMN
# Out:
# Education                     3
# YearJoined                    7
# City                          3
# PaymentTier                   3
# Age                          20
# Gender                        2
# EverBenched                   2
# ExperienceInCurrentDomain     8
# LeaveOrNot                    2
# dtype: int64

# %%
df['YearJoined'].unique()   # specified unique values in specific column
# Out:
# array([2017, 2013, 2014, 2016, 2015, 2012, 2018], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   YearJoined                 4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
df.isnull()
# Out:
#       Education  YearJoined   City  PaymentTier    Age  Gender  EverBenched  \
# 0         False       False  False        False  False   False        False
# 1         False       False  False        False  False   False        False
# 2         False       False  False        False  False   False        False
# 3         False       False  False        False  False   False        False
# 4         False       False  False        False  False   False        False
# ...         ...         ...    ...          ...    ...     ...          ...
# 4648      False       False  False        False  False   False        False
# 4649      False       False  False        False  False   False        False
# 4650      False       False  False        False  False   False        False
# 4651      False       False  False        False  False   False        False
# 4652      False       False  False        False  False   False        False
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   YearJoined                 4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
df.dtypes
# Out:
# Education                    object
# YearJoined                    int64
# City                         object
# PaymentTier                   int64
# Age                           int64
# Gender                       object
# EverBenched                  object
# ExperienceInCurrentDomain     int64
# LeaveOrNot                    int64
# dtype: object

# %% [markdown]
# ## TO SEARCH SOME SPECIFIC DATA IN CERTAIN COLUMN

# %%
df[df['Age']==30]
# Out:
#       Education  YearJoined       City  PaymentTier  Age  Gender EverBenched  \
# 18    Bachelors        2015       Pune            2   30  Female          No
# 29      Masters        2017  New Delhi            2   30  Female          No
# 35    Bachelors        2014  Bangalore            1   30  Female          No
# 39    Bachelors        2014       Pune            3   30    Male         Yes
# 42    Bachelors        2013  Bangalore            3   30    Male          No
# ...         ...         ...        ...          ...  ...     ...         ...
# 4613  Bachelors        2014  Bangalore            3   30    Male          No
# 4622  Bachelors        2017       Pune            1   30    Male          No
# 4627        PHD        2012  Bangalore            3   30  Female          No
# 4647  Bachelors        2016       Pune            3   30    Male          No
# 4651  Bachelors        2012  Bangalore            3   30    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
df[(df['Age']==30) & (df['City']== 'Pune')]
# Out:
#       Education  YearJoined  City  PaymentTier  Age  Gender EverBenched  \
# 18    Bachelors        2015  Pune            2   30  Female          No
# 39    Bachelors        2014  Pune            3   30    Male         Yes
# 2010  Bachelors        2014  Pune            3   30    Male          No
# 2021    Masters        2015  Pune            3   30  Female          No
# 2027    Masters        2017  Pune            2   30  Female          No
# 2028  Bachelors        2015  Pune            2   30  Female         Yes
# 2065  Bachelors        2016  Pune            3   30    Male          No
# 2095  Bachelors        2015  Pune            2   30    Male          No
# 2107    Masters        2017  Pune            2   30    Male          No
# 2168  Bachelors        2013  Pune            3   30    Male          No
# 2211  Bachelors        2015  Pune            2   30  Female         Yes
# 2213  Bachelors        2013  Pune            3   30    Male          No
# ...

# %%
df[(df['Age']==30) & (df['City']== 'Pune') & (df["Education"]=='Bachelors')]
# Out:
#       Education  YearJoined  City  PaymentTier  Age  Gender EverBenched  \
# 18    Bachelors        2015  Pune            2   30  Female          No
# 39    Bachelors        2014  Pune            3   30    Male         Yes
# 2010  Bachelors        2014  Pune            3   30    Male          No
# 2028  Bachelors        2015  Pune            2   30  Female         Yes
# 2065  Bachelors        2016  Pune            3   30    Male          No
# 2095  Bachelors        2015  Pune            2   30    Male          No
# 2168  Bachelors        2013  Pune            3   30    Male          No
# 2211  Bachelors        2015  Pune            2   30  Female         Yes
# 2213  Bachelors        2013  Pune            3   30    Male          No
# 2227  Bachelors        2017  Pune            2   30  Female          No
# 2232  Bachelors        2017  Pune            3   30    Male          No
# 2290  Bachelors        2012  Pune            2   30  Female          No
# ...

# %%
df[(df['Age']==30) & (df['City']== 'Pune') & (df["Education"]=='Bachelors')& (df["Gender"]=='Female')]
# Out:
#       Education  YearJoined  City  PaymentTier  Age  Gender EverBenched  \
# 18    Bachelors        2015  Pune            2   30  Female          No
# 2028  Bachelors        2015  Pune            2   30  Female         Yes
# 2211  Bachelors        2015  Pune            2   30  Female         Yes
# 2227  Bachelors        2017  Pune            2   30  Female          No
# 2290  Bachelors        2012  Pune            2   30  Female          No
# 2313  Bachelors        2015  Pune            3   30  Female          No
# 2359  Bachelors        2015  Pune            2   30  Female          No
# 2421  Bachelors        2016  Pune            2   30  Female          No
# 2591  Bachelors        2015  Pune            3   30  Female          No
# 2602  Bachelors        2018  Pune            3   30  Female          No
# 2640  Bachelors        2015  Pune            1   30  Female          No
# 2643  Bachelors        2017  Pune            2   30  Female          No
# ...

# %%
df[(df['Age']==30) & (df['City']== 'Pune') & (df["Education"]=='Bachelors')& (df["Gender"]=='Female') & (df["YearJoined"]==2015)]
# Out:
#       Education  YearJoined  City  PaymentTier  Age  Gender EverBenched  \
# 18    Bachelors        2015  Pune            2   30  Female          No
# 2028  Bachelors        2015  Pune            2   30  Female         Yes
# 2211  Bachelors        2015  Pune            2   30  Female         Yes
# 2313  Bachelors        2015  Pune            3   30  Female          No
# 2359  Bachelors        2015  Pune            2   30  Female          No
# 2591  Bachelors        2015  Pune            3   30  Female          No
# 2640  Bachelors        2015  Pune            1   30  Female          No
# 2767  Bachelors        2015  Pune            2   30  Female          No
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 18                            0           1
# 2028                          1           1
# 2211                          1           1
# 2313                          1           1
# 2359                          2           1
# 2591                          0           1
# ...

# %%
df[(df['Age']==30) & (df['City']== 'Pune') & (df["Education"]=='Bachelors')& (df["Gender"]=='Female')&  (df["YearJoined"]==2015)& (df['PaymentTier']==2)]
# Out:
#       Education  YearJoined  City  PaymentTier  Age  Gender EverBenched  \
# 18    Bachelors        2015  Pune            2   30  Female          No
# 2028  Bachelors        2015  Pune            2   30  Female         Yes
# 2211  Bachelors        2015  Pune            2   30  Female         Yes
# 2359  Bachelors        2015  Pune            2   30  Female          No
# 2767  Bachelors        2015  Pune            2   30  Female          No
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 18                            0           1
# 2028                          1           1
# 2211                          1           1
# 2359                          2           1
# 2767                          1           1

# %%
df[(df['Age']==30) & (df['City']== 'Pune') & (df["Education"]=='Bachelors')& (df["Gender"]=='Female')&  (df["YearJoined"]==2015)& (df['PaymentTier']==2) & (df["EverBenched"]=="Yes")]
# Out:
#       Education  YearJoined  City  PaymentTier  Age  Gender EverBenched  \
# 2028  Bachelors        2015  Pune            2   30  Female         Yes
# 2211  Bachelors        2015  Pune            2   30  Female         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 2028                          1           1
# 2211                          1           1

# %%
df.tail()
# Out:
#       Education  YearJoined       City  PaymentTier  Age  Gender EverBenched  \
# 4648  Bachelors        2013  Bangalore            3   26  Female          No
# 4649    Masters        2013       Pune            2   37    Male          No
# 4650    Masters        2018  New Delhi            3   27    Male          No
# 4651  Bachelors        2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors        2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0

# %%
df[(df['Age']>=30)]
# Out:
#       Education  YearJoined       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors        2017  Bangalore            3   34    Male          No
# 2     Bachelors        2014  New Delhi            3   38  Female          No
# 6     Bachelors        2015  New Delhi            3   38    Male          No
# 7     Bachelors        2016  Bangalore            3   34  Female          No
# 9       Masters        2017  New Delhi            2   37    Male          No
# ...         ...         ...        ...          ...  ...     ...         ...
# 4645    Masters        2017       Pune            2   31  Female          No
# 4647  Bachelors        2016       Pune            3   30    Male          No
# 4649    Masters        2013       Pune            2   37    Male          No
# 4651  Bachelors        2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors        2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
df[(df['Age']>=30) & (df['City']=='Bangalore')]
# Out:
#       Education  YearJoined       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors        2017  Bangalore            3   34    Male          No
# 7     Bachelors        2016  Bangalore            3   34  Female          No
# 13    Bachelors        2016  Bangalore            3   39    Male          No
# 14    Bachelors        2012  Bangalore            3   37    Male          No
# 16    Bachelors        2014  Bangalore            3   34  Female          No
# ...         ...         ...        ...          ...  ...     ...         ...
# 4641  Bachelors        2016  Bangalore            1   33  Female          No
# 4642  Bachelors        2012  Bangalore            3   36  Female          No
# 4643  Bachelors        2013  Bangalore            3   31  Female          No
# 4651  Bachelors        2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors        2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
df.sort_values(by ='Age')   # the default order will be ascending so the result will be same even after you apply the condition of ascending = True in this case
# Out:
#       Education  YearJoined       City  PaymentTier  Age  Gender EverBenched  \
# 63    Bachelors        2014       Pune            1   22  Female          No
# 4357  Bachelors        2014  Bangalore            3   22    Male          No
# 4377  Bachelors        2013  Bangalore            3   22    Male         Yes
# 4048  Bachelors        2014  Bangalore            3   22    Male          No
# 4225  Bachelors        2016  Bangalore            3   22    Male          No
# ...         ...         ...        ...          ...  ...     ...         ...
# 3004  Bachelors        2016  Bangalore            3   41    Male          No
# 3775    Masters        2017  Bangalore            2   41    Male         Yes
# 3355  Bachelors        2016  Bangalore            3   41    Male          No
# 3173  Bachelors        2013  Bangalore            3   41    Male          No
# 3247  Bachelors        2012  Bangalore            3   41  Female          No
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
df.sort_values(by ='Age', ascending = False)
# Out:
#       Education  YearJoined       City  PaymentTier  Age  Gender EverBenched  \
# 3914        PHD        2017       Pune            3   41    Male          No
# 3535  Bachelors        2016  Bangalore            3   41    Male          No
# 3764  Bachelors        2016  Bangalore            3   41    Male          No
# 3114  Bachelors        2016  Bangalore            3   41    Male          No
# 3355  Bachelors        2016  Bangalore            3   41    Male          No
# ...         ...         ...        ...          ...  ...     ...         ...
# 4225  Bachelors        2016  Bangalore            3   22    Male          No
# 4234  Bachelors        2016       Pune            3   22    Male          No
# 25    Bachelors        2013  Bangalore            3   22  Female         Yes
# 4248    Masters        2017  New Delhi            2   22    Male          No
# 4338        PHD        2015  New Delhi            3   22  Female          No
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
df.dropna()  #for removing rows with missing values
# Out:
#       Education  YearJoined       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors        2017  Bangalore            3   34    Male          No
# 1     Bachelors        2013       Pune            1   28  Female          No
# 2     Bachelors        2014  New Delhi            3   38  Female          No
# 3       Masters        2016  Bangalore            3   27    Male          No
# 4       Masters        2017       Pune            3   24    Male         Yes
# ...         ...         ...        ...          ...  ...     ...         ...
# 4648  Bachelors        2013  Bangalore            3   26  Female          No
# 4649    Masters        2013       Pune            2   37    Male          No
# 4650    Masters        2018  New Delhi            3   27    Male          No
# 4651  Bachelors        2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors        2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %% [markdown]
# ##### Query method can be use to filter the data in a more concise and readable manner

# %%
df.query('Age > 25 and City =="Pune"')
# Out:
#       Education  YearJoined  City  PaymentTier  Age  Gender EverBenched  \
# 1     Bachelors        2013  Pune            1   28  Female          No
# 11    Bachelors        2016  Pune            3   34    Male          No
# 12    Bachelors        2018  Pune            3   32    Male         Yes
# 17    Bachelors        2014  Pune            3   34    Male          No
# 18    Bachelors        2015  Pune            2   30  Female          No
# ...         ...         ...   ...          ...  ...     ...         ...
# 4625  Bachelors        2013  Pune            3   37    Male          No
# 4644  Bachelors        2015  Pune            3   32  Female         Yes
# 4645    Masters        2017  Pune            2   31  Female          No
# 4647  Bachelors        2016  Pune            3   30    Male          No
# 4649    Masters        2013  Pune            2   37    Male          No
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 1                             3           1
# ...

# %%
### The alternative to query method 
#Traditional indexing  method
df[(df['Age'] >=25) & (df['City']=='Pune')]
## Query method is considered easier
# Out:
#       Education  YearJoined  City  PaymentTier  Age  Gender EverBenched  \
# 1     Bachelors        2013  Pune            1   28  Female          No
# 11    Bachelors        2016  Pune            3   34    Male          No
# 12    Bachelors        2018  Pune            3   32    Male         Yes
# 17    Bachelors        2014  Pune            3   34    Male          No
# 18    Bachelors        2015  Pune            2   30  Female          No
# ...         ...         ...   ...          ...  ...     ...         ...
# 4630  Bachelors        2012  Pune            3   25  Female          No
# 4644  Bachelors        2015  Pune            3   32  Female         Yes
# 4645    Masters        2017  Pune            2   31  Female          No
# 4647  Bachelors        2016  Pune            3   30    Male          No
# 4649    Masters        2013  Pune            2   37    Male          No
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 1                             3           1
# ...

# %% [markdown]
# # EDA

# %%
x =df['Age']
y=df['YearJoined']
plt.xlabel = 'Age'
plt.ylabel='YearJoined'
plt.bar(x,y, color='r')
plt.title("Sample")

plt.show()

# %%
df.describe() #numerical data
# Out:
#         YearJoined  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
sns.heatmap(df.isnull(),yticklabels=False, cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df.City.value_counts()
# Out:
# City
# Bangalore    2228
# Pune         1268
# New Delhi    1157
# Name: count, dtype: int64

# %%
df.City.value_counts().index
# Out:
# Index(['Bangalore', 'Pune', 'New Delhi'], dtype='object', name='City')

# %%
df_city = df.City.value_counts().index

# %%
City_Values=df.City.value_counts().values

# %% [markdown]
# # Pie Chart

# %%
c = ['r','g','b']
plt.pie(City_Values,labels=df_city,autopct ='%1.2f%%', colors = c)
plt.show()

# %% [markdown]
# #### Observation : Most of the employees are from Bangalore(47.88%) , followed by Pune(27.25%) and New Delhi(24.87%)

# %%
df.columns
# Out:
# Index(['Education', 'YearJoined', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot'],
#       dtype='object')

# %%
df.groupby(['Age','Gender','City']).size()
# Out:
# Age  Gender  City
# 22   Female  Bangalore     6
#              New Delhi     5
#              Pune          8
#      Male    Bangalore    18
#              New Delhi     9
#                           ..
# 41   Female  New Delhi    12
#              Pune          7
#      Male    Bangalore    35
#              New Delhi    10
#              Pune         11
# Length: 120, dtype: int64

# %%
df_Gender =df['Gender'].value_counts().index

# %%
Gender_counts=df['Gender'].value_counts().values

# %%
plt.pie(Gender_counts, labels=df_Gender,autopct='%1.2f%%')
plt.legend(loc=1)   #loc =1 is used for the assigning the place where we can put the indexes male and female, upper right side. If we use loc =2 , the indexex will be shifted on upper left side
plt.title("Pie Chart")
plt.show()

# %% [markdown]
# ##### Observation: Most of the employees are MALE (59.70%)

# %%
sns.barplot(x ="Gender", y="Age" ,data= df, color= 'r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[139], line 2
#       1 sns.barplot(x ="Gender", y="Age" ,data= df, color= 'r')
# ----> 2 sns.legend(loc =2)
#
# AttributeError: module 'seaborn' has no attribute 'legend'

# %%
#obseration : There is no variations in age and gender in this data

# %% [markdown]
# # Countplot

# %%
df.head()
# Out:
#    Education  YearJoined       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors        2017  Bangalore            3   34    Male          No
# 1  Bachelors        2013       Pune            1   28  Female          No
# 2  Bachelors        2014  New Delhi            3   38  Female          No
# 3    Masters        2016  Bangalore            3   27    Male          No
# 4    Masters        2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df.groupby(['Education','YearJoined','Age']).size().index
# Out:
# MultiIndex([('Bachelors', 2012, 22),
#             ('Bachelors', 2012, 23),
#             ('Bachelors', 2012, 24),
#             ('Bachelors', 2012, 25),
#             ('Bachelors', 2012, 26),
#             ('Bachelors', 2012, 27),
#             ('Bachelors', 2012, 28),
#             ('Bachelors', 2012, 29),
#             ('Bachelors', 2012, 30),
#             ('Bachelors', 2012, 31),
#             ...
#             (      'PHD', 2018, 28),
#             (      'PHD', 2018, 29),
#             (      'PHD', 2018, 30),
#             (      'PHD', 2018, 33),
#             (      'PHD', 2018, 34),
#             (      'PHD', 2018, 35),
#             (      'PHD', 2018, 36),
#             (      'PHD', 2018, 37),
#             (      'PHD', 2018, 38),
#             (      'PHD', 2018, 40)],
#            names=['Education', 'YearJoined', 'Age'], length=340)

# %%
sns.countplot(x ="Education",color ='b',data = df)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %% [markdown]
# ## Observation: Most of the employees have an education qualification of bachelors, followed by MASTERS AND pHD RESPECTIVELY

# %%
df_Education= df[(df['Education']=='Bachelors')].value_counts().index

# %%
Education_Counts=df[(df['Education']=='Bachelors')].value_counts().values

# %%
plt.pie(Education_Counts,labels =df_Education, data =df)
plt.show()

# %%
df.columns
# Out:
# Index(['Education', 'YearJoined', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot'],
#       dtype='object')

# %% [markdown]
# ## Finding the number of females and males who have joined the job in 2015

# %%
df[(df['YearJoined'] == 2015)].groupby('Gender').size().reset_index()
# Out:
#    Gender    0
# 0  Female  440
# 1    Male  341

# %% [markdown]
# ## Finding the number of females who have joined the job in 2015

# %%
df[(df['YearJoined']==2015) & (df['Gender']=='Female')].shape[0]
# Out:
# 440

# %% [markdown]
# Finding the number of employees from Pune

# %%
df[(df['City']=='Pune')].shape[0]
# Out:
# 1268
